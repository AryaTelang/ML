# %% [markdown]
# ## Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Predict water temperature based on salinity

# %%
bottle=pd.read_csv("/content/drive/MyDrive/watersalinity&temp/bottle.csv")
cast=pd.read_csv("/content/drive/MyDrive/watersalinity&temp/cast.csv")
# Out:
# <ipython-input-15-1ea11bc52c00>:1: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   bottle=pd.read_csv("/content/drive/MyDrive/watersalinity&temp/bottle.csv")
# <ipython-input-15-1ea11bc52c00>:2: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   cast=pd.read_csv("/content/drive/MyDrive/watersalinity&temp/cast.csv")

# %%
bottle
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0             1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1             1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2             1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3             1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4             1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
# ...         ...      ...          ...                                     ...
# 864858    34404   864859  093.4 026.4  20-1611SR-MX-310-2239-09340264-0000A-7
# 864859    34404   864860  093.4 026.4  20-1611SR-MX-310-2239-09340264-0002A-3
# 864860    34404   864861  093.4 026.4  20-1611SR-MX-310-2239-09340264-0005A-3
# 864861    34404   864862  093.4 026.4  20-1611SR-MX-310-2239-09340264-0010A-3
# 864862    34404   864863  093.4 026.4  20-1611SR-MX-310-2239-09340264-0015A-3
#
# ...

# %%
bottle

df1=bottle[['T_degC',"Salnty"]]
temp=df1['T_degC']
sal=['Salnty']
#df1=df1.to_csv()

# %%
plt.scatter(df1['T_degC'],df1['Salnty'],color='green',alpha=0.5,s=1)
plt.xlabel("temperature")
plt.ylabel("salinity")
plt.show()

# %%
from sklearn import linear_model

# %%
df1
# Out:
#         T_degC   Salnty
# 0       10.500  33.4400
# 1       10.460  33.4400
# 2       10.460  33.4370
# 3       10.450  33.4200
# 4       10.450  33.4210
# ...        ...      ...
# 864858  18.744  33.4083
# 864859  18.744  33.4083
# 864860  18.692  33.4150
# 864861  18.161  33.4062
# 864862  17.533  33.3880
#
# [864863 rows x 2 columns]

# %%
 reg=linear_model.LinearRegression()
 #reg.fit(df1['Salnty'],df1.T_degC)

# %%
df1['Salnty'].isnull().sum()
df1['Salnty']=df1['Salnty'].fillna(df1['Salnty'].mean())
df1['T_degC'].isnull().sum()
df1['T_degC']=df1['T_degC'].fillna(df1['T_degC'].mean())
# Out:
# <ipython-input-22-401a83295b61>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Salnty']=df1['Salnty'].fillna(df1['Salnty'].mean())
# <ipython-input-22-401a83295b61>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['T_degC']=df1['T_degC'].fillna(df1['T_degC'].mean())

# %%
reg.fit(df1[['Salnty']],df1['T_degC'])
# Out:
# LinearRegression()

# %%
#y=mx+b ,m
print(reg.coef_)
#b
print(reg.intercept_)
reg.predict([[33]])
# Out:
# [-4.6013678]
# 166.51157504806744
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([14.6664377])

# %%
waterSal=[0,12.45,100]
pred=[]
for i in waterSal:
  pred.append(reg.predict([[i]]))
pred
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [array([166.51157505]), array([109.22454596]), array([-293.62520479])]

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Probabilistic values, predicted value is categorical. Used for classification
# We use Sigmoid or Logit Function. (1/(1+e^-z))
# Convert input into range 0 or 1

# %%
df=pd.read_csv('/content/insurance_data.csv')

# %%
plt.scatter(df.age,df.bought_insurance)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df[['age']],df[['bought_insurance']],train_size=0.9)

# %%
X_test
# Out:
#     age
# 5    56
# 11   28
# 2    47

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 1])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.11006663, 0.88993337],
#        [0.80243726, 0.19756274],
#        [0.2753308 , 0.7246692 ]])

# %%
model.predict([[25]])
#0 probability a 25 yr old would buy an insurance
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
